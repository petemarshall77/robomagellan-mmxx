# %%
import pandas as pd

# %%
monty_gps = pd.read_csv('gps-capture-3.csv')

# %%
monty_gps.head()
# Out:
#        time  seconds status        lat         lon  delta_lat  delta_lon  \
# 0  22:08:43        0      A  33.778455 -118.418500   0.000000   0.000000
# 1  22:08:44        1      A  33.778452 -118.418500  -0.370650  -0.000000
# 2  22:08:45        2      A  33.778447 -118.418502  -0.926624  -0.154041
# 3  22:08:46        3      A  33.778447 -118.418502  -0.926624  -0.154041
# 4  22:08:47        4      A  33.778445 -118.418502  -1.111949  -0.154041
#
#    distance     bearing  speed   track
# 0  0.000000    0.000000   0.83  157.08
# 1  0.370650  180.000000   0.92  157.08
# 2  0.939341  189.438465   0.71  157.08
# 3  0.939341  189.438465   0.68  157.08
# 4  1.122568  187.887116   1.06  157.08

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10,10]

# %%
plt.scatter(monty_gps.delta_lon, monty_gps.delta_lat, alpha=0.5)
plt.axis('square')
# Out:
# (-145.0194336352336,
#  12.236735284013633,
#  -10.699316085655601,
#  146.55685283359165)

# %%
monty_gps.track.plot()

# %%
monty_gps.speed.plot()
